# %%
number = 23 
number
type(number)
# Out:
# int

# %%
FloatNumber = 13.67 
type(FloatNumber)
# Out:
# float

# %%
# area of traingle 
base  = 24 
height = 14
area = ( base * height ) / 2 
print(area)
# Out:
# 168.0

# %%
# checking the type of area 
type(area)
# Out:
# float

# %%
# using round fun to round area 
round(area)
# Out:
# 168

# %%
# understanding math fun in pyton 
import math 
value = 23.17
math.floor(value)
# Out:
# 23

# %%
# using math ceil it return grater value 
math.ceil(value)
# Out:
# 24

# %%
# understanding the math.sqrt
math.sqrt(value)

# %%
# now using round function and understand it properly 
value2 = 234.78654
round( value2)  # it returs 235 it always provide grater value
round(value2 , 3) # it returns 234.787
round ( value2 , 1 )
# Out:
# 234.8

# %%
# understand math.pi 
print(math.pi)
# Out:
# 3.141592653589793

# %%
round(math.pi , 2 )
# Out:
# 3.14

# %%
 x = 10
y = 3
print(x/y) # it returns 3.3333333333333335
print ( x // y ) # its return quotients 3 to retrive integer point 
print ( x % y )  # its return reminder 1 
print ( x ** y ) # its works like 10*10*10
# Out:
# 3.3333333333333335
# 3
# 1
# 1000

# %%
# binary representation of whole number 
format ( 4 , 'b' )
# Out:
# '100'
