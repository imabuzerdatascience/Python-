# %%
# sets are mutable and frozen sets are immutable
myset = set([1,2,3,4,5,1,2,3,4,6])
myset #sets remove duplicate data
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
# another way to write a set
myset = {1,2,3,4,5,6,1 ,2,4,56,7,2}
myset
# Out:
# {1, 2, 3, 4, 5, 6, 7, 56}

# %%
myset[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 myset[0]
#
# TypeError: 'set' object is not subscriptable

# %%
list(myset)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 56]

# %%
print( 2 in myset)
# Out:
# True

# %%
menu = {"Pizza", "Burger", "Pasta", "Salad", "Sandwich"}
menu
# Out:
# {'Burger', 'Pasta', 'Pizza', 'Salad', 'Sandwich'}

# %%
menu.add("chicken")
menu
# Out:
# {'Burger', 'Pasta', 'Pizza', 'Salad', 'Sandwich', 'chicken'}

# %%
menu.remove("Pizza")
menu
# Out:
# {'Burger', 'Pasta', 'Salad', 'Sandwich', 'chicken'}

# %%
# frozen set 
myset = frozenset([1,2,3,5,6,78,1,2,3,4])
myset
# Out:
# frozenset({1, 2, 3, 4, 5, 6, 78})

# %%
myset.add(23)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 myset.add(23)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
print("Salad" in menu)
# Out:
# True

# %%
a = {"Amit", "Rahul", "Sneha", "Priya"}
b = {"Rahul", "Priya", "Vikram", "Anjali"}
#find the common person
print(a&b)
print(a-b) #person availabe in a
print(a|b) #it gives both but not dupicate data
# Out:
# {'Priya', 'Rahul'}
# {'Sneha', 'Amit'}
# {'Sneha', 'Priya', 'Rahul', 'Vikram', 'Anjali', 'Amit'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 7
#       5 print(a-b) #person availabe in a
#       6 print(a|b) #it gives both but not dupicate data
# ----> 7 print(aub)
#
# NameError: name 'aub' is not defined
