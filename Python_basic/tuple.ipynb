# %%
# tuple 
tuple = (12, 34, 56, 67)
tuple
# Out:
# (12, 34, 56, 67)

# %%
tuple[0]
# Out:
# 12

# %%
tuple[0:]
# Out:
# (12, 34, 56, 67)

# %%
tuple[0] = 56
# it throw an erro because tuple is immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 tuple[0] = 56
#
# TypeError: 'tuple' object does not support item assignment

# %%
def find_pe_pb(price , eps , book_value ) :
 pe = price/eps
 pb = price/book_value
 return pe ,pb  #it know as a  tuple
pe_ratio , pb_ratio = find_pe_pb(100, 6 , 8 )
print(pe_ratio)
# Out:
# 16.666666666666668
