# %%
can = "beans"
can
# Out:
# 'beans'

# %%
can = "apple"
print(can)
# Out:
# apple

# %%
id(can)
# Out:
# 1296511525120

# %%
can = 23 
can
# Out:
# 23

# %%
type(can)
# Out:
# int

# %%
decimal = 27.98
type(decimal)
# Out:
# float

# %%
pizza = 100
print(pizza)
samosa = 20.12
icecream = 100
# Out:
# 100

# %%
total = pizza + samosa + icecream 
total
# Out:
# 220.12

# %%
type(total)
# Out:
# float

# %%
 limit = total > 200 
limit
# Out:
# True

# %%
total < 200
# Out:
# False

# %%
type (limit)
# Out:
# bool

# %%
can = "apple" 23 True
can
# Out:
#   Cell In[21], line 1
#     can = "apple" 23 True
#                   ^
# SyntaxError: invalid syntax

# %%
can = "apple" , 23 , True
can
# Out:
# ('apple', 23, True)

# %%
can , num , boo = "str" , 23 , True
print(can , num , boo)
# Out:
# str 23 True

# %%
$naame = "bakar"
$name
# Out:
#   Cell In[24], line 1
#     $naame = "bakar"
#     ^
# SyntaxError: invalid syntax
