# %%
import pandas as pd 
df = pd.read_csv("weather_data.csv")
df
# Out:
#         day  temperature  windspeed     event
# 0  1/1/2017           32          6      Rain
# 1  1/2/2017       -99999          7     Sunny
# 2  1/3/2017           28     -99999      Snow
# 3  1/4/2017       -99999          7  no event
# 4  1/5/2017           32     -99999      Rain
# 5  1/6/2017           31          2     Sunny
# 6  1/6/2017           34     -88888  no event

# %%
import numpy as np 
df.replace([-99999 , -88888], np.nan)
# Out:
#         day  temperature  windspeed     event
# 0  1/1/2017         32.0        6.0      Rain
# 1  1/2/2017          NaN        7.0     Sunny
# 2  1/3/2017         28.0        NaN      Snow
# 3  1/4/2017          NaN        7.0  no event
# 4  1/5/2017         32.0        NaN      Rain
# 5  1/6/2017         31.0        2.0     Sunny
# 6  1/6/2017         34.0        NaN  no event

# %%
df.replace({
    "temperature" : -99999 ,
    "windspeed" : [-99999 , -88888] ,
    "event" : "no event" 
    
},np.nan)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0    NaN
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        NaN    NaN

# %%
# for all the column 
df.replace({
    -99999 : np.nan, 
    -88888 : np.nan ,
    "no event" : "sunny"
    
})
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0  sunny
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        NaN  sunny

# %%
df = pd.DataFrame({
    "score" : [ "good" , "v.good" , "v.v.good" , "excellent" , "outstanding"] ,
    "student" : [ "abuzer" , "bakar" , "danish" , "omar" , "mannu"]
})
df
# Out:
#          score student
# 0         good  abuzer
# 1       v.good   bakar
# 2     v.v.good  danish
# 3    excellent    omar
# 4  outstanding   mannu

# %%
df.replace(["good" , "v.good" , "v.v.good" , "excellent" , "outstanding"],[1,2,3,4,5])
df
# Out:
#    score student
# 0     28  abuzer
# 1     36   bakar
# 2     78  danish
# 3     98    omar
# 4     56   mannu
